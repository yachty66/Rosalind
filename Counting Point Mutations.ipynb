# %%
def hammingDistance():
    s = input()
    t = input()
    counter = 0
    for i in range(len(s)):
        if s[i] != t[i]:
            counter += 1
    return counter

# %%
print(hammingDistance())
# Out:
# ...
# ...
# 500

# %%
# Out:
# ö
